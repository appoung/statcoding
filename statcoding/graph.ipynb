# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([1, 2, 3, 4], [12, 43, 25, 45])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([10,20,30,40],label='asc')
plt.plot([40,30,20,10],label='desc')
plt.legend() # 레이블 범례보여줌
plt.show()
